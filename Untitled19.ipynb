# %% [markdown]
# <a href="https://colab.research.google.com/github/Skkodnikk/popakota/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import neighbors
from sklearn import linear_model
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('/content/heart_failure_clinical_records_dataset.csv')
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                      1  265000.00               1.9           130    1
# 1                      0  263358.03               1.1           136    1
# 2                      0  162000.00               1.3           129    1
# 3                      0  210000.00               1.9           137    1
# 4                      0  327000.00               2.7           116    0
# ..                   ...        ...               ...           ...  ...
# 294                    1  155000.00               1.1           143    1
# 295                    0  270000.00               1.2           139    0
# 296                    0  742000.00               0.8           138    0
# 297                    0  140000.00               1.4           140    1
# 298                    0  395000.00               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %% [markdown]
# На основе представленной информации мы приходим к выводу, что необходимо выполнить масштабирование данных.

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %% [markdown]
# - Тип данных: pandas.core.frame.DataFrame
# - Количество записей: 299
# - Индексы: от 0 до 298
# - Общее количество столбцов: 13 Типы данных:
# - Числовые (int64): 10 столбцов
# - Числовые (float64): 3 столбца
# - Категорирование делать не нужно.
# - Использование памяти: 30.5 КБ

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# 25%            30.000000             0.000000  212500.000000
# 50%            38.000000             0.000000  262000.000000
# 75%            45.000000             1.000000  303500.000000
# max            80.000000             1.000000  850000.000000
#
#        serum_creatinine  serum_sodium         sex    smoking        time  \
# count         299.00000    299.000000  299.000000  299.00000  299.000000
# mean            1.39388    136.625418    0.648829    0.32107  130.260870
# std             1.03451      4.412477    0.478136    0.46767   77.614208
# min             0.50000    113.000000    0.000000    0.00000    4.000000
# 25%             0.90000    134.000000    0.000000    0.00000   73.000000
# 50%             1.10000    137.000000    1.000000    0.00000  115.000000
# 75%             1.40000    140.000000    1.000000    1.00000  203.000000
# max             9.40000    148.000000    1.000000    1.00000  285.000000
#
#        DEATH_EVENT
# count    299.00000
# mean       0.32107
# std        0.46767
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000

# %%
df.hist(figsize=(15, 15))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'anaemia'}>,
#         <Axes: title={'center': 'creatinine_phosphokinase'}>,
#         <Axes: title={'center': 'diabetes'}>],
#        [<Axes: title={'center': 'ejection_fraction'}>,
#         <Axes: title={'center': 'high_blood_pressure'}>,
#         <Axes: title={'center': 'platelets'}>,
#         <Axes: title={'center': 'serum_creatinine'}>],
#        [<Axes: title={'center': 'serum_sodium'}>,
#         <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'smoking'}>,
#         <Axes: title={'center': 'time'}>],
#        [<Axes: title={'center': 'DEATH_EVENT'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
df.isnull().sum().max()
# Out:
# 0

# %%
X = df.drop('time', axis=1)
Y = df['time']

# %%
X.info()
Y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(9)
# memory usage: 28.2 KB
# <class 'pandas.core.series.Series'>
# RangeIndex: 299 entries, 0 to 298
# Series name: time
# Non-Null Count  Dtype
# --------------  -----
# 299 non-null    int64
# dtypes: int64(1)
# memory usage: 2.5 KB

# %%
scaler = StandardScaler().fit(X)
std = scaler. transform(X)
X_std = pd.DataFrame(std)
X_std
# Out:
#            0         1         2         3         4         5             6   \
# 0    1.192945 -0.871105  0.000166 -0.847579 -1.530560  1.359272  1.681648e-02
# 1   -0.491279 -0.871105  7.514640 -0.847579 -0.007077 -0.735688  7.535660e-09
# 2    0.350833 -0.871105 -0.449939 -0.847579 -1.530560 -0.735688 -1.038073e+00
# 3   -0.912335  1.147968 -0.486071 -0.847579 -1.530560 -0.735688 -5.464741e-01
# 4    0.350833  1.147968 -0.435486  1.179830 -1.530560 -0.735688  6.517986e-01
# ..        ...       ...       ...       ...       ...       ...           ...
# 294  0.098199 -0.871105 -0.537688  1.179830 -0.007077  1.359272 -1.109765e+00
# 295 -0.491279 -0.871105  1.278215 -0.847579 -0.007077 -0.735688  6.802472e-02
# 296 -1.333392 -0.871105  1.525979  1.179830  1.854958 -0.735688  4.902082e+00
# 297 -1.333392 -0.871105  1.890398 -0.847579 -0.007077 -0.735688 -1.263389e+00
# 298 -0.912335 -0.871105 -0.398321 -0.847579  0.585389 -0.735688  1.348231e+00
#
#            7         8         9         10        11
# 0    0.490057 -1.504036  0.735688 -0.687682  1.454161
# 1   -0.284552 -0.141976  0.735688 -0.687682  1.454161
# 2   -0.090900 -1.731046  0.735688  1.454161  1.454161
# 3    0.490057  0.085034  0.735688 -0.687682  1.454161
# 4    1.264666 -4.682176 -1.359272 -0.687682  1.454161
# ..        ...       ...       ...       ...       ...
# 294 -0.284552  1.447094  0.735688  1.454161 -0.687682
# 295 -0.187726  0.539054 -1.359272 -0.687682 -0.687682
# 296 -0.575031  0.312044 -1.359272 -0.687682 -0.687682
# 297  0.005926  0.766064  0.735688  1.454161 -0.687682
# 298  0.199578 -0.141976  0.735688  1.454161 -0.687682
#
# [299 rows x 12 columns]

# %% [markdown]
# Выполнили стандартизацию для последующего анализа и применения в различных задачах.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_std, Y, train_size=0.7)
Y_train.shape, Y_test.shape
# Out:
# ((209,), (90,))

# %%
print('no dead', round(df['DEATH_EVENT'].value_counts()[0]/len(df) * 100,2), '% данных')
print('yes dead', round(df['DEATH_EVENT'].value_counts()[1]/len(df) * 100,2), '% данных')
# Out:
# no dead 67.89 % данных
# yes dead 32.11 % данных

# %%
knn = neighbors.KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train, Y_train)
y_pred_knn_test = knn.predict(X_test)
y_pred_knn_train = knn.predict(X_train)
print(f'KNN - Accuracy test:', accuracy_score(Y_test, y_pred_knn_test))
print(f'KNN - Accuracy train:', accuracy_score(Y_train, y_pred_knn_train))
print(f'KNN - F1 test:', f1_score(Y_test, y_pred_knn_test, average='macro'))
print(f'KNN - F1 train:', f1_score(Y_train, y_pred_knn_train, average='macro'))
# Out:
# KNN - Accuracy test: 0.011111111111111112
# KNN - Accuracy train: 0.5454545454545454
# KNN - F1 test: 0.0032362459546925564
# KNN - F1 train: 0.4720347707847708

# %%
model_dtr = DecisionTreeClassifier()
model_dtr.fit(X_train, Y_train)
Y_train_pred_dtr = model_dtr.predict(X_train)
Y_test_pred_dtr = model_dtr.predict(X_test)

print(f'Дерево решений - Accuracy test:', accuracy_score(Y_test, Y_test_pred_dtr))
print(f'Дерево решений - Accuracy train:', accuracy_score(Y_train, Y_train_pred_dtr))
print(f'Дерево решений - F1 test:', f1_score(Y_test, Y_test_pred_dtr, average='macro'))
print(f'Дерево решений - F1 train:', f1_score(Y_train, Y_train_pred_dtr, average='macro'))
# Out:
# Дерево решений - Accuracy test: 0.011111111111111112
# Дерево решений - Accuracy train: 1.0
# Дерево решений - F1 test: 0.003738317757009346
# Дерево решений - F1 train: 1.0

# %%
model_rfr = RandomForestClassifier()
model_rfr.fit(X_train, Y_train)
Y_test_pred_rfr = model_rfr.predict(X_test)
Y_train_pred_rfr = model_rfr.predict(X_train)

print(f'Случайный лес - Accuracy test:', accuracy_score(Y_test, Y_test_pred_dtr))
print(f'Случайный лес - Accuracy train:', accuracy_score(Y_train, Y_train_pred_dtr))
print(f'Случайный лес - F1 test:', f1_score(Y_test, Y_test_pred_dtr, average='macro'))
print(f'Случайный лес - F1 train:', f1_score(Y_train, Y_train_pred_dtr, average='macro'))
# Out:
# Случайный лес - Accuracy test: 0.011111111111111112
# Случайный лес - Accuracy train: 1.0
# Случайный лес - F1 test: 0.003738317757009346
# Случайный лес - F1 train: 1.0

# %%
from sklearn.model_selection import GridSearchCV
knn = neighbors.KNeighborsClassifier()
params = {'n_neighbors': [1, 2, 3, 4, 5, 6, 7, 8, 9], 'metric':['euclidean','cityblock']}
grid = GridSearchCV(estimator = knn, param_grid = params)
grid.fit(X_train, Y_train)
print(grid.best_score_)
print(grid.best_estimator_.n_neighbors)
print(grid.best_estimator_.metric)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# 0.03844367015098722
# 6
# cityblock
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %%
knn = neighbors.KNeighborsClassifier(n_neighbors=6)
knn.fit(X_train, Y_train)
y_pred_knn_test = knn.predict(X_test)
y_pred_knn_train = knn.predict(X_train)
print(f'KNN - Accuracy test:', accuracy_score(Y_test, y_pred_knn_test))
print(f'KNN - Accuracy train:', accuracy_score(Y_train, y_pred_knn_train))
print(f'KNN - F1 test:', f1_score(Y_test, y_pred_knn_test, average='macro'))
print(f'KNN - F1 train:', f1_score(Y_train, y_pred_knn_train, average='macro'))
# Out:
# KNN - Accuracy test: 0.03333333333333333
# KNN - Accuracy train: 0.21052631578947367
# KNN - F1 test: 0.012749615975422427
# KNN - F1 train: 0.10804117587205822
