# %% [markdown]
# <a href="https://colab.research.google.com/github/Skkodnikk/popakota/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#1
bank = pd.read_csv('/content/bank.csv',
                   sep = ';')
bank
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank.shape
# Out:
# (4521, 17)

# %%
#2
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
bank.tail()
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %%
bank.head(7)
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   30     unemployed  married    primary      no     1787      no   no
# 1   33       services  married  secondary      no     4789     yes  yes
# 2   35     management   single   tertiary      no     1350     yes   no
# 3   30     management  married   tertiary      no     1476     yes  yes
# 4   59    blue-collar  married  secondary      no        0     yes   no
# 5   35     management   single   tertiary      no      747      no   no
# 6   36  self-employed  married   tertiary      no      307     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# ...

# %%
#3
bank1 = pd.read_csv('/content/bank (1).csv',
                   sep = ';',
                   nrows = 8,
                   index_col = 'job')
bank1
# Out:
#                age  marital  education default  balance housing loan  \
# job
# unemployed      30  married    primary      no     1787      no   no
# services        33  married  secondary      no     4789     yes  yes
# management      35   single   tertiary      no     1350     yes   no
# management      30  married   tertiary      no     1476     yes  yes
# blue-collar     59  married  secondary      no        0     yes   no
# management      35   single   tertiary      no      747      no   no
# self-employed   36  married   tertiary      no      307     yes   no
# technician      39  married  secondary      no      147     yes   no
#
#                 contact  day month  duration  campaign  pdays  previous  \
# job
# unemployed     cellular   19   oct        79         1     -1         0
# services       cellular   11   may       220         1    339         4
# management     cellular   16   apr       185         1    330         1
# ...

# %%
#4
bank1 = pd.read_csv('/content/bank (1).csv',
                   sep = ';',
                   nrows = 8,
                   index_col = 'job',
                   usecols = ['job', 'age', 'marital', 'education', 'balance', 'duration'])
bank1.head()
# Out:
#              age  marital  education  balance  duration
# job
# unemployed    30  married    primary     1787        79
# services      33  married  secondary     4789       220
# management    35   single   tertiary     1350       185
# management    30  married   tertiary     1476       199
# blue-collar   59  married  secondary        0       226

# %%
#5
bank1 = pd.read_csv('/content/bank (1).csv',
                    sep = ';')
bank1.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
bank1.columns
# Out:
# Index(['age', 'marital', 'education', 'default', 'balance', 'housing', 'loan',
#        'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous',
#        'poutcome', 'y'],
#       dtype='object')

# %%
bank1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, unemployed to technician
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        8 non-null      int64
#  1   marital    8 non-null      object
#  2   education  8 non-null      object
#  3   default    8 non-null      object
#  4   balance    8 non-null      int64
#  5   housing    8 non-null      object
#  6   loan       8 non-null      object
#  7   contact    8 non-null      object
#  8   day        8 non-null      int64
#  9   month      8 non-null      object
#  10  duration   8 non-null      int64
#  11  campaign   8 non-null      int64
#  12  pdays      8 non-null      int64
#  13  previous   8 non-null      int64
#  14  poutcome   8 non-null      object
#  15  y          8 non-null      object
# dtypes: int64(7), object(9)
# memory usage: 1.1+ KB

# %%
bank1.hist(figsize = (20,30))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'balance'}>,
#         <Axes: title={'center': 'day'}>],
#        [<Axes: title={'center': 'duration'}>,
#         <Axes: title={'center': 'campaign'}>,
#         <Axes: title={'center': 'pdays'}>],
#        [<Axes: title={'center': 'previous'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
bank1.boxplot('balance')
# Out:
# <Axes: >

# %%
#6
bank2 = pd.read_csv('/content/bank (2).csv', sep=';', usecols=['job', 'age', 'marital', 'education', 'balance', 'duration'], index_col='job')
b = bank2.loc['retired']
b
# Out:
#          age   marital  education  balance  duration
# job
# retired   67   married    unknown      696       119
# retired   68  divorced  secondary     4189       897
# retired   78  divorced    primary      229        97
# retired   36    single  secondary      101       314
# retired   63   married  secondary      415       323
# ...      ...       ...        ...      ...       ...
# retired   83  divorced    primary     1097       181
# retired   41    single    primary        0       239
# retired   57   married   tertiary       31       260
# retired   57   married  secondary      107        85
# retired   65   married    primary      493       622
#
# [230 rows x 5 columns]
