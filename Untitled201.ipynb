# %% [markdown]
# <a href="https://colab.research.google.com/github/Skkodnikk/popakota/blob/main/Untitled201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Копия creditcard.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# Учитывая предоставленные данные, можно заключить, что необходимо провести масштабирование некоторых колонок. В противном случае, различия в масштабах могут вызвать ситуацию, при которой алгоритмы машинного обучения будут склонны к признакам с высокими значениями, игнорируя более информативные, но с меньшими значениями.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# В данном датасете необходимо масштабировать столбцы "Amount" и "Time"

# %%
plt.figure(figsize=(12, 9))
plt.subplot(2, 2, 1)
plt.hist(df['Time'], bins=50)
plt.title('Распределение Time')
plt.xlabel('Время')
plt.ylabel('Количество транзакций')

plt.subplot(2, 2, 2)
sns.distplot(df['Time'], kde=False)
plt.title('Распределение Time')
plt.xlabel('Время')
plt.ylabel('Количество транзакций')

plt.subplot(2, 2, 3)
plt.hist(df['Amount'], bins=50)
plt.title('Распределение Amount')
plt.xlabel('Сумма')
plt.ylabel('Количество транзакций')

plt.subplot(2, 2, 4)
sns.distplot(df['Amount'], kde=True)
plt.title('Распределение Amount')
plt.xlabel('Сумма')
plt.ylabel('Плотность')
# Out:
# <ipython-input-31-3545ebf9f622>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Time'], kde=False)
# <ipython-input-31-3545ebf9f622>:21: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Amount'], kde=True)
# Text(0, 0.5, 'Плотность')

# %% [markdown]
# Построили графики распределения для столбцов: Time и Amount.

# %%
from sklearn.preprocessing import RobustScaler
rob_scaler = RobustScaler()
df['Time1'] = rob_scaler.fit_transform(df['Time'].values.reshape(-1,1))
df['Amount1'] = rob_scaler.fit_transform(df['Amount'].values.reshape(-1,1))

# %% [markdown]
# В данном датасете необходимо масштабировать столбцы "Amount" и "Time".

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V23       V24       V25       V26       V27  \
# 0  0.098698  0.363787  ... -0.110474  0.066928  0.128539 -0.189115  0.133558
# 1  0.085102 -0.255425  ...  0.101288 -0.339846  0.167170  0.125895 -0.008983
# 2  0.247676 -1.514654  ...  0.909412 -0.689281 -0.327642 -0.139097 -0.055353
# 3  0.377436 -1.387024  ... -0.190321 -1.175575  0.647376 -0.221929  0.062723
# 4 -0.270533  0.817739  ... -0.137458  0.141267 -0.206010  0.502292  0.219422
#
# ...

# %%
df1= df.drop(['Time', 'Amount'], axis=1)
df1.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V22       V23       V24       V25  \
# 0  0.098698  0.363787  0.090794  ...  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425 -0.166974  ... -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  0.207643  ...  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024 -0.054952  ...  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  0.753074  ...  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Class     Time1   Amount1
# ...

# %%
df1.isnull().sum()
# Out:
# V1         0
# V2         0
# V3         0
# V4         0
# V5         0
# V6         0
# V7         0
# V8         0
# V9         0
# V10        0
# V11        0
# V12        0
# V13        0
# V14        0
# V15        0
# V16        0
# V17        0
# V18        0
# V19        0
# V20        0
# V21        0
# V22        0
# V23        0
# V24        0
# V25        0
# V26        0
# V27        0
# V28        0
# Class      0
# Time1      0
# Amount1    0
# dtype: int64

# %%
print('no cheater', round(df['Class'].value_counts()[0]/len(df) * 100,2), '% данных')
print('yes cheater', round(df['Class'].value_counts()[1]/len(df) * 100,2), '% данных')
# Out:
# no cheater 99.83 % данных
# yes cheater 0.17 % данных

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
x = df.drop('Class', axis=1)
y = df['Class']
skf = StratifiedKFold(n_splits=5, random_state=None, shuffle=False) # Выполним разбиение на 5 фолдов
for train_index, test_index in skf.split(x, y):
  orig_x_train, orig_x_test = x.iloc[train_index], x.iloc[test_index]
  orig_y_train, orig_y_test = y.iloc[train_index], y.iloc[test_index]
orig_x_train = orig_x_train.values
orig_x_test = orig_x_test.values
orig_y_train = orig_y_train.values
orig_y_test = orig_y_test.values
train_unique_label, train_counts_label = np.unique(orig_y_train, return_counts=True)
test_unique_label, test_counts_label = np.unique(orig_y_test, return_counts=True)
print('Распределение классов: \n')
print("Обучающий набор:", train_counts_label/ len(orig_y_train))
print("Тестовый набор:", test_counts_label/ len(orig_y_test))
# Out:
# Распределение классов:
#
# Обучающий набор: [0.99827076 0.00172924]
# Тестовый набор: [0.99827952 0.00172048]

# %%
df2 = df1.sample(frac=1)
df_1 = df1.loc[df['Class']==1]
df_2 = df1.loc[df['Class']==0][:492]
normal_df = pd.concat([df_1, df_2])
new_df = normal_df.sample(frac=1, random_state=42)
print(new_df.shape)
new_df.head()
# Out:
# (984, 31)
#               V1        V2        V3        V4        V5        V6        V7  \
# 121    -0.427191  0.745708  1.761811 -0.165130  0.058298 -0.213413  0.647323
# 248296 -0.613696  3.698772 -5.534941  5.620486  1.649263 -2.335145 -0.907188
# 239     1.171439  0.474974  0.011761  1.264303  0.116234 -0.865986  0.554393
# 239501 -6.682832 -2.714268 -5.774530  1.449792 -0.661836 -1.148650  0.849686
# 143336 -6.713407  3.921104 -9.746678  5.148263 -5.151563 -2.099389 -5.937767
#
#               V8        V9       V10  ...       V22       V23       V24  \
# 121     0.073464 -0.291864  0.064800  ... -0.432070  0.013164  0.161606
# 248296  0.706362 -3.747646 -4.230984  ... -0.471379 -0.075890 -0.667909
# 239    -0.276375 -0.471302  0.029104  ...  0.278843 -0.097491  0.426278
# 239501  0.433427 -1.315646 -2.796332  ...  1.187013  0.335821  0.215683
# 143336  3.578780 -4.684952 -8.537758  ... -0.451086  0.127214 -0.339450
#
# ...

# %%
print('Распределение классов в подвыборке')
print(new_df['Class'].value_counts()/len(new_df))
sns.countplot(x='Class', data = new_df, palette='dark')
plt.title('Распределение классов', fontsize=14)
plt.show()
# Out:
# Распределение классов в подвыборке
# Class
# 0    0.5
# 1    0.5
# Name: count, dtype: float64
# <ipython-input-40-1a6f94f07bfe>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Class', data = new_df, palette='dark')

# %%
sub_sample_corr = new_df.corr()
plt.figure(figsize=(30, 15))
sns.heatmap(sub_sample_corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Выводы:
# При рассмотрении матрицы корреляции становится очевидно, что признаки V2, V4 и V11 имеют положительную корреляцию. Это указывает на то, что отклик Class находится в прямой зависимости от этих признаков: с ростом их значений увеличивается вероятность совершения мошеннической операции. В то же время признаки V10, V12 и V14 демонстрируют отрицательную корреляцию, что подразумевает, что уменьшение их значений также ведет к повышению вероятности мошенничества.

# %%
from scipy.stats import norm
f, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(1,6, figsize=(25, 6))

v14_fraud_dist = new_df['V14'].loc[new_df['Class'] == 1].values
sns.distplot(v14_fraud_dist, ax=ax1, fit = norm, color = 'red')
ax1.set_title('Распределение признака V14', fontsize=14)

v12_fraud_dist = new_df['V12'].loc[new_df['Class'] == 1].values
sns.distplot(v12_fraud_dist, ax=ax2, fit = norm, color = 'green')
ax2.set_title('Распределение признака V12', fontsize=14)

v10_fraud_dist = new_df['V10'].loc[new_df['Class'] == 1].values
sns.distplot(v10_fraud_dist, ax=ax3, fit = norm, color = 'blue')
ax3.set_title('Распределение признака V10', fontsize=14)

v2_fraud_dist = new_df['V2'].loc[new_df['Class'] == 1].values
sns.distplot(v2_fraud_dist, ax=ax4, fit = norm, color = 'gold')
ax4.set_title('Распределение признака V2', fontsize=14)

v4_fraud_dist = new_df['V4'].loc[new_df['Class'] == 1].values
sns.distplot(v4_fraud_dist, ax=ax5, fit = norm, color = 'gray')
ax5.set_title('Распределение признака V4', fontsize=14)

v11_fraud_dist = new_df['V11'].loc[new_df['Class'] == 1].values
sns.distplot(v11_fraud_dist, ax=ax6, fit = norm, color = 'purple')
ax6.set_title('Распределение признака V11', fontsize=14)

plt.show()
# Out:
# <ipython-input-46-0b9cf78f0736>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(v14_fraud_dist, ax=ax1, fit = norm, color = 'red')
# <ipython-input-46-0b9cf78f0736>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
v14_fraud = new_df['V14'].loc[new_df['Class'] == 1].values
q25, q75 = np.percentile(v14_fraud, 25), np.percentile(v14_fraud, 75)
print('Квартиль 25: {} | Квартиль 75: {}'.format(q25, q75))
v14_iqr = q75 - q25
print('iqr: {}'.format(v14_iqr))

v14_cut_off = v14_iqr * 1.5
v14_lower, v14_upper = q25 - v14_cut_off, q75 +v14_cut_off
print('Порог: {}'.format(v14_cut_off))
print('V14 нижняя граница: {}'.format(v14_lower))
print('V14 верхняя граница: {}'.format(v14_upper))

outliers = [x for x in v14_fraud if x < v14_lower or x > v14_upper]
print('Количество выбросов: {}'.format(len(outliers)))

new_df = new_df.drop(new_df[(new_df['V14'] > v14_upper) | (new_df['V14'] < v14_lower)].index)
# Out:
# Квартиль 25: -9.692722964972386 | Квартиль 75: -4.282820849486865
# iqr: 5.409902115485521
# Порог: 8.114853173228282
# V14 нижняя граница: -17.807576138200666
# V14 верхняя граница: 3.8320323237414167
# Количество выбросов: 4

# %%
plt.figure(figsize=(12, 9))
sns.boxplot( data = new_df, x='Class', y='V14')
plt.title('V14 vs Class')
plt.show()

# %% [markdown]
# В данном случае было выявлено 4 выброса, которые были удалены.

# %%
v12_fraud = new_df['V12'].loc[new_df['Class'] == 1].values
q25, q75 = np.percentile(v12_fraud, 25), np.percentile(v12_fraud, 75)
print('Квартиль 25: {} | Квартиль 75: {}'.format(q25, q75))
v12_iqr = q75 - q25
print('iqr: {}'.format(v12_iqr))

v12_cut_off = v12_iqr * 1.5
v12_lower, v12_upper = q25 - v12_cut_off, q75 +v12_cut_off
print('Порог: {}'.format(v12_cut_off))
print('V12 нижняя граница: {}'.format(v12_lower))
print('V12 верхняя граница: {}'.format(v12_upper))

outliers = [x for x in v12_fraud if x < v12_lower or x > v12_upper]
print('Количество выбросов: {}'.format(len(outliers)))

new_df = new_df.drop(new_df[(new_df['V12'] > v12_upper) | (new_df['V12'] < v12_lower)].index)
# Out:
# Квартиль 25: -8.67303320439115 | Квартиль 75: -2.893030568676315
# iqr: 5.780002635714835
# Порог: 8.670003953572252
# V12 нижняя граница: -17.3430371579634
# V12 верхняя граница: 5.776973384895937
# Количество выбросов: 4

# %%
plt.figure(figsize=(12, 9))
sns.boxplot(x='Class', y='V12', data = new_df)
plt.title('V12 vs Class')
plt.show()

# %% [markdown]
# В данном случае было выявлено 4 выброса, которые были удалены.

# %%
v10_fraud = new_df['V10'].loc[new_df['Class'] == 1].values
q25, q75 = np.percentile(v10_fraud, 25), np.percentile(v10_fraud, 75)
print('Квартиль 25: {} | Квартиль 75: {}'.format(q25, q75))
v10_iqr = q75 - q25
print('iqr: {}'.format(v10_iqr))

v10_cut_off = v10_iqr * 1.5
v10_lower, v10_upper = q25 - v10_cut_off, q75 +v10_cut_off
print('Порог: {}'.format(v10_cut_off))
print('V10 нижняя граница: {}'.format(v10_lower))
print('V10 верхняя граница: {}'.format(v10_upper))

outliers = [x for x in v10_fraud if x < v10_lower or x > v10_upper]
print('Количество выбросов: {}'.format(len(outliers)))

new_df = new_df.drop(new_df[(new_df['V10'] > v10_upper) | (new_df['V10'] < v10_lower)].index)
# Out:
# Квартиль 25: -5.93649657102067 | Квартиль 75: -2.192565859033865
# iqr: 3.743930711986805
# Порог: 5.6158960679802075
# V10 нижняя граница: -11.552392639000878
# V10 верхняя граница: 3.4233302089463424
# Количество выбросов: 7

# %%
plt.figure(figsize=(12, 9))
sns.boxplot(x='Class', y='V10', data = new_df)
plt.title('V10 vs Class')
plt.show()

# %% [markdown]
# В данном случае было обнаружено 27 выбросов.
# Обновляя код еще три раз, кол-во выбросов до 7.
#
# Код удаляет выбросы из new_df, что приводит к сокращению числа значений, используемых в каждом запуске. Например, если в предыдущем запуске некоторые выбросы уже были исключены, они больше не будут учитываться, что может снизить количество вновь выявленных выбросов.

# %%
v2_fraud = new_df['V2'].loc[new_df['Class'] == 1].values
q25, q75 = np.percentile(v2_fraud, 25), np.percentile(v2_fraud, 75)
print('Квартиль 25: {} | Квартиль 75: {}'.format(q25, q75))
v2_iqr = q75 - q25
print('iqr: {}'.format(v2_iqr))

v2_cut_off = v2_iqr * 1.5
v2_lower, v2_upper = q25 - v2_cut_off, q75 + v2_cut_off
print('Порог: {}'.format(v2_cut_off))
print('V2 нижняя граница: {}'.format(v2_lower))
print('V2 верхняя граница: {}'.format(v2_upper))

outliers = [x for x in v2_fraud if x < v2_lower or x > v2_upper]
print('Количество выбросов: {}'.format(len(outliers)))

new_df = new_df.drop(new_df[(new_df['V2'] > v2_upper) | (new_df['V2'] < v2_lower)].index)
# Out:
# Квартиль 25: 1.091775007430235 | Квартиль 75: 3.28300523758511
# iqr: 2.1912302301548747
# Порог: 3.286845345232312
# V2 нижняя граница: -2.1950703378020773
# V2 верхняя граница: 6.569850582817422
# Количество выбросов: 4

# %%
plt.figure(figsize=(12, 9))
sns.boxplot(x='Class', y='V2', data = new_df)
plt.title('V2 vs Class')
plt.show()

# %% [markdown]
# В данном случае было обнаружено 46 выбросов.
# Обновляя код еще один раз, кол-во выбросов до 4.

# %%
v4_fraud = new_df['V4'].loc[new_df['Class'] == 1].values
q25, q75 = np.percentile(v4_fraud, 25), np.percentile(v4_fraud, 75)
print('Квартиль 25: {} | Квартиль 75: {}'.format(q25, q75))
v4_iqr = q75 - q25
print('iqr: {}'.format(v4_iqr))

v4_cut_off = v4_iqr * 1.5
v4_lower, v4_upper = q25 - v4_cut_off, q75 + v4_cut_off
print('Порог: {}'.format(v4_cut_off))
print('V4 нижняя граница: {}'.format(v4_lower))
print('V4 верхняя граница: {}'.format(v4_upper))

outliers = [x for x in v4_fraud if x < v4_lower or x > v4_upper]
print('Количество выбросов: {}'.format(len(outliers)))

new_df = new_df.drop(new_df[(new_df['V4'] > v4_upper) | (new_df['V4'] < v4_lower)].index)
# Out:
# Квартиль 25: 2.005525195040595 | Квартиль 75: 5.314540579251865
# iqr: 3.3090153842112704
# Порог: 4.963523076316905
# V4 нижняя граница: -2.9579978812763104
# V4 верхняя граница: 10.27806365556877
# Количество выбросов: 0

# %%
plt.figure(figsize=(12, 9))
sns.boxplot(x='Class', y='V4', data = new_df)
plt.title('V4 vs Class')
plt.show()

# %% [markdown]
# В данном случае было обнаружено 0 выбросов.

# %%
v11_fraud = new_df['V11'].loc[new_df['Class'] == 1].values
q25, q75 = np.percentile(v11_fraud, 25), np.percentile(v11_fraud, 75)
print('Квартиль 25: {} | Квартиль 75: {}'.format(q25, q75))
v11_iqr = q75 - q25
print('iqr: {}'.format(v11_iqr))

v11_cut_off = v11_iqr * 1.5
v11_lower, v11_upper = q25 - v11_cut_off, q75 + v11_cut_off
print('Порог: {}'.format(v11_cut_off))
print('V11 нижняя граница: {}'.format(v11_lower))
print('V11 верхняя граница: {}'.format(v11_upper))

outliers = [x for x in v11_fraud if x < v11_lower or x > v11_upper]
print('Количество выбросов: {}'.format(len(outliers)))

new_df = new_df.drop(new_df[(new_df['V11'] > v11_upper) | (new_df['V11'] < v11_lower)].index)
# Out:
# Квартиль 25: 1.54347485295268 | Квартиль 75: 4.39689599208663
# iqr: 2.8534211391339506
# Порог: 4.280131708700926
# V11 нижняя граница: -2.7366568557482465
# V11 верхняя граница: 8.677027700787557
# Количество выбросов: 2

# %%
plt.figure(figsize=(12, 9))
sns.boxplot(x='Class', y='V11', data = new_df)
plt.title('V11 vs Class')
plt.show()

# %% [markdown]
# В данном случае было обнаружено 2 выброса, которые были удалены.

# %% [markdown]
# Общие выводы:
#
# - Программа идентифицирует и устраняет выбросы в столбце V14, ориентируясь на
# значения класса 1 (возможно, мошенничество или иной целевой класс). Для выявления выбросов применяется метод интерквартильного размаха (IQR), который определяется как разница между 75-м и 25-м процентилями, позволяя оценить разброс значений в центральной части распределения.
# - После вычисления этих процентилей программа устанавливает границы (нижнюю и верхнюю), за пределами которых значения V14 считаются выбросами. Для их расчета используется множитель 1.5, применяемый к IQR.
# - Значения, находящиеся ниже нижней границы или выше верхней, удаляются из датафрейма new_df, что способствует улучшению качества данных. В данной ситуации было выявлено 4 выброса, которые были устранены.
# - Удаление выбросов способствует улучшению статистических характеристик данных, что, в свою очередь, может повысить точность моделей машинного обучения и их обобщающую способность.
# - Выбросы могут искажать результаты анализа, затруднять выявление трендов и оказывать влияние на результаты дальнейших исследований. Их удаление помогает достичь более надежных результатов.
# - Устранение выбросов позволяет сделать данные более репрезентативными, что особенно актуально при анализе аномалий в данных класса 1.
